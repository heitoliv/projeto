# %%
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Garantir reprodutibilidade total
os.environ['PYTHONHASHSEED'] = '42'
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()

df = pd.read_csv('data_per_month.csv')  # Apenas a coluna de passageiros

df = df['Total Renewable Energy']
# Normalização dos dados
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(df.values.reshape(-1, 1))

# Função para criar sequência de dados
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

# Definir tamanho da janela
time_steps = 12
X, y = create_sequences(data_scaled, time_steps)

# Divisão dos dados
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Construção da rede LSTM
model = Sequential([
    LSTM(64, activation='relu', return_sequences=True, input_shape=(time_steps, 1)),
    LSTM(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Treinamento do modelo
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Avaliação do modelo
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}, Test MAE: {test_mae:.4f}')

# Fazer previsões
y_pred = model.predict(X_test)

# Reverter a normalização
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

# Cálculo das métricas de regressão
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_inv, y_pred_inv)

print(f'MAE: {mae:.4f}')
print(f'MSE: {mse:.4f}')
print(f'RMSE: {rmse:.4f}')
print(f'R² Score: {r2:.4f}')

# Plot da curva de aprendizado
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Loss (Treino)')
plt.plot(history.history['val_loss'], label='Loss (Validação)')
plt.xlabel('Épocas')
plt.ylabel('Erro Quadrático Médio')
plt.legend()
plt.title('Curva de Aprendizado')
plt.show()

# Plot dos resultados
plt.figure(figsize=(10, 5))
plt.plot(y_test_inv, label='Real')
plt.plot(y_pred_inv, label='Previsto')
plt.xlabel('Tempo')
plt.ylabel('Número de Passageiros')
plt.legend()
plt.title('Comparação entre valores reais e previstos')
plt.show()
# Out:
# Epoch 1/150
# C:\Users\olihe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0753 - mae: 0.2454 - val_loss: 0.0076 - val_mae: 0.0702
# Epoch 2/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - mae: 0.0958 - val_loss: 0.0731 - val_mae: 0.2614
# Epoch 3/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0594 - val_loss: 0.0163 - val_mae: 0.1111
# Epoch 4/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mae: 0.0445 - val_loss: 0.0045 - val_mae: 0.0544
# Epoch 5/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0419 - val_loss: 0.0045 - val_mae: 0.0549
# Epoch 6/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0400 - val_loss: 0.0045 - val_mae: 0.0541
# Epoch 7/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mae: 0.0399 - val_loss: 0.0044 - val_mae: 0.0541
# Epoch 8/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0398 - val_loss: 0.0044 - val_mae: 0.0539
# Epoch 9/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mae: 0.0397 - val_loss: 0.0044 - val_mae: 0.0538
# Epoch 10/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0397 - val_loss: 0.0044 - val_mae: 0.0538
# Epoch 11/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0397 - val_loss: 0.0044 - val_mae: 0.0536
# Epoch 12/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mae: 0.0396 - val_loss: 0.0044 - val_mae: 0.0535
# Epoch 13/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0396 - val_loss: 0.0044 - val_mae: 0.0534
# Epoch 14/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0395 - val_loss: 0.0044 - val_mae: 0.0533
# Epoch 15/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mae: 0.0395 - val_loss: 0.0044 - val_mae: 0.0532
# Epoch 16/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0394 - val_loss: 0.0043 - val_mae: 0.0530
# Epoch 17/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mae: 0.0393 - val_loss: 0.0043 - val_mae: 0.0529
# Epoch 18/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0393 - val_loss: 0.0043 - val_mae: 0.0527
# Epoch 19/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mae: 0.0392 - val_loss: 0.0043 - val_mae: 0.0526
# Epoch 20/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mae: 0.0391 - val_loss: 0.0043 - val_mae: 0.0525
# Epoch 21/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0391 - val_loss: 0.0042 - val_mae: 0.0523
# Epoch 22/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0390 - val_loss: 0.0042 - val_mae: 0.0523
# Epoch 23/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0390 - val_loss: 0.0042 - val_mae: 0.0521
# Epoch 24/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mae: 0.0389 - val_loss: 0.0042 - val_mae: 0.0520
# Epoch 25/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0389 - val_loss: 0.0042 - val_mae: 0.0520
# Epoch 26/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0388 - val_loss: 0.0042 - val_mae: 0.0518
# Epoch 27/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0387 - val_loss: 0.0042 - val_mae: 0.0517
# Epoch 28/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mae: 0.0387 - val_loss: 0.0042 - val_mae: 0.0516
# Epoch 29/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0386 - val_loss: 0.0041 - val_mae: 0.0515
# Epoch 30/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mae: 0.0386 - val_loss: 0.0042 - val_mae: 0.0515
# Epoch 31/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0385 - val_loss: 0.0041 - val_mae: 0.0513
# Epoch 32/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0385 - val_loss: 0.0041 - val_mae: 0.0513
# Epoch 33/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0384 - val_loss: 0.0041 - val_mae: 0.0513
# Epoch 34/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - mae: 0.0384 - val_loss: 0.0041 - val_mae: 0.0513
# Epoch 35/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mae: 0.0383 - val_loss: 0.0041 - val_mae: 0.0510
# Epoch 36/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mae: 0.0382 - val_loss: 0.0041 - val_mae: 0.0509
# Epoch 37/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mae: 0.0381 - val_loss: 0.0041 - val_mae: 0.0511
# Epoch 38/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mae: 0.0381 - val_loss: 0.0040 - val_mae: 0.0509
# Epoch 39/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mae: 0.0380 - val_loss: 0.0040 - val_mae: 0.0510
# Epoch 40/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0379 - val_loss: 0.0040 - val_mae: 0.0507
# Epoch 41/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mae: 0.0379 - val_loss: 0.0040 - val_mae: 0.0507
# Epoch 42/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0378 - val_loss: 0.0039 - val_mae: 0.0503
# Epoch 43/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0377 - val_loss: 0.0040 - val_mae: 0.0504
# Epoch 44/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0376 - val_loss: 0.0039 - val_mae: 0.0501
# Epoch 45/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0376 - val_loss: 0.0039 - val_mae: 0.0502
# Epoch 46/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0375 - val_loss: 0.0039 - val_mae: 0.0498
# Epoch 47/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0374 - val_loss: 0.0039 - val_mae: 0.0497
# Epoch 48/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0373 - val_loss: 0.0038 - val_mae: 0.0492
# Epoch 49/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0372 - val_loss: 0.0038 - val_mae: 0.0490
# Epoch 50/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0371 - val_loss: 0.0037 - val_mae: 0.0488
# Epoch 51/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0370 - val_loss: 0.0037 - val_mae: 0.0484
# Epoch 52/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0369 - val_loss: 0.0037 - val_mae: 0.0481
# Epoch 53/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0369 - val_loss: 0.0036 - val_mae: 0.0477
# Epoch 54/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0368 - val_loss: 0.0036 - val_mae: 0.0473
# Epoch 55/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0367 - val_loss: 0.0035 - val_mae: 0.0469
# Epoch 56/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0366 - val_loss: 0.0035 - val_mae: 0.0470
# Epoch 57/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0365 - val_loss: 0.0035 - val_mae: 0.0466
# Epoch 58/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mae: 0.0365 - val_loss: 0.0034 - val_mae: 0.0462
# Epoch 59/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mae: 0.0364 - val_loss: 0.0034 - val_mae: 0.0459
# Epoch 60/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mae: 0.0363 - val_loss: 0.0034 - val_mae: 0.0455
# Epoch 61/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mae: 0.0362 - val_loss: 0.0033 - val_mae: 0.0454
# Epoch 62/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0361 - val_loss: 0.0033 - val_mae: 0.0451
# Epoch 63/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0360 - val_loss: 0.0033 - val_mae: 0.0449
# Epoch 64/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mae: 0.0360 - val_loss: 0.0033 - val_mae: 0.0446
# Epoch 65/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0359 - val_loss: 0.0032 - val_mae: 0.0444
# Epoch 66/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0358 - val_loss: 0.0032 - val_mae: 0.0442
# Epoch 67/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0357 - val_loss: 0.0032 - val_mae: 0.0439
# Epoch 68/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0356 - val_loss: 0.0032 - val_mae: 0.0438
# Epoch 69/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0355 - val_loss: 0.0032 - val_mae: 0.0435
# Epoch 70/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0355 - val_loss: 0.0032 - val_mae: 0.0435
# Epoch 71/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0354 - val_loss: 0.0032 - val_mae: 0.0433
# Epoch 72/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0353 - val_loss: 0.0032 - val_mae: 0.0432
# Epoch 73/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0352 - val_loss: 0.0033 - val_mae: 0.0436
# Epoch 74/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0351 - val_loss: 0.0032 - val_mae: 0.0433
# Epoch 75/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0350 - val_loss: 0.0033 - val_mae: 0.0437
# Epoch 76/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0350 - val_loss: 0.0032 - val_mae: 0.0433
# Epoch 77/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0349 - val_loss: 0.0033 - val_mae: 0.0436
# Epoch 78/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0348 - val_loss: 0.0034 - val_mae: 0.0435
# Epoch 79/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0347 - val_loss: 0.0035 - val_mae: 0.0440
# Epoch 80/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0346 - val_loss: 0.0033 - val_mae: 0.0431
# Epoch 81/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0345 - val_loss: 0.0035 - val_mae: 0.0438
# Epoch 82/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0345 - val_loss: 0.0035 - val_mae: 0.0437
# Epoch 83/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0344 - val_loss: 0.0035 - val_mae: 0.0442
# Epoch 84/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0343 - val_loss: 0.0036 - val_mae: 0.0445
# Epoch 85/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mae: 0.0342 - val_loss: 0.0034 - val_mae: 0.0434
# Epoch 86/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0341 - val_loss: 0.0035 - val_mae: 0.0443
# Epoch 87/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0341 - val_loss: 0.0036 - val_mae: 0.0448
# Epoch 88/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0341 - val_loss: 0.0036 - val_mae: 0.0448
# Epoch 89/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0341 - val_loss: 0.0036 - val_mae: 0.0450
# Epoch 90/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0340 - val_loss: 0.0037 - val_mae: 0.0455
# Epoch 91/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0339 - val_loss: 0.0037 - val_mae: 0.0455
# Epoch 92/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0339 - val_loss: 0.0036 - val_mae: 0.0447
# Epoch 93/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0339 - val_loss: 0.0038 - val_mae: 0.0460
# Epoch 94/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0338 - val_loss: 0.0037 - val_mae: 0.0449
# Epoch 95/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0338 - val_loss: 0.0038 - val_mae: 0.0460
# Epoch 96/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0338 - val_loss: 0.0037 - val_mae: 0.0448
# Epoch 97/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0337 - val_loss: 0.0037 - val_mae: 0.0453
# Epoch 98/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0337 - val_loss: 0.0037 - val_mae: 0.0453
# Epoch 99/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0337 - val_loss: 0.0038 - val_mae: 0.0456
# Epoch 100/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0037 - val_mae: 0.0452
# Epoch 101/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0038 - val_mae: 0.0457
# Epoch 102/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0038 - val_mae: 0.0457
# Epoch 103/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0039 - val_mae: 0.0464
# Epoch 104/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0335 - val_loss: 0.0037 - val_mae: 0.0445
# Epoch 105/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0335 - val_loss: 0.0039 - val_mae: 0.0458
# Epoch 106/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0334 - val_loss: 0.0040 - val_mae: 0.0466
# Epoch 107/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0335 - val_loss: 0.0039 - val_mae: 0.0461
# Epoch 108/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0335 - val_loss: 0.0038 - val_mae: 0.0448
# Epoch 109/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0334 - val_loss: 0.0039 - val_mae: 0.0458
# Epoch 110/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0334 - val_loss: 0.0040 - val_mae: 0.0465
# Epoch 111/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0334 - val_loss: 0.0039 - val_mae: 0.0456
# Epoch 112/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0334 - val_loss: 0.0038 - val_mae: 0.0447
# Epoch 113/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0333 - val_loss: 0.0044 - val_mae: 0.0489
# Epoch 114/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0035 - val_mae: 0.0430
# Epoch 115/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0338 - val_loss: 0.0033 - val_mae: 0.0420
# Epoch 116/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0332 - val_loss: 0.0038 - val_mae: 0.0448
# Epoch 117/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0329 - val_loss: 0.0038 - val_mae: 0.0448
# Epoch 118/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0332 - val_loss: 0.0033 - val_mae: 0.0420
# Epoch 119/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0333 - val_loss: 0.0034 - val_mae: 0.0423
# Epoch 120/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0332 - val_loss: 0.0034 - val_mae: 0.0426
# Epoch 121/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0332 - val_loss: 0.0034 - val_mae: 0.0425
# Epoch 122/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0331 - val_loss: 0.0033 - val_mae: 0.0421
# Epoch 123/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0331 - val_loss: 0.0033 - val_mae: 0.0419
# Epoch 124/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0330 - val_loss: 0.0034 - val_mae: 0.0420
# Epoch 125/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0330 - val_loss: 0.0033 - val_mae: 0.0419
# Epoch 126/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0331 - val_loss: 0.0033 - val_mae: 0.0419
# Epoch 127/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0331 - val_loss: 0.0034 - val_mae: 0.0423
# Epoch 128/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0330 - val_loss: 0.0034 - val_mae: 0.0422
# Epoch 129/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0329 - val_loss: 0.0035 - val_mae: 0.0426
# Epoch 130/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0329 - val_loss: 0.0035 - val_mae: 0.0426
# Epoch 131/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0330 - val_loss: 0.0035 - val_mae: 0.0429
# Epoch 132/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0330 - val_loss: 0.0034 - val_mae: 0.0422
# Epoch 133/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0329 - val_loss: 0.0036 - val_mae: 0.0432
# Epoch 134/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0037 - val_mae: 0.0436
# Epoch 135/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0036 - val_mae: 0.0434
# Epoch 136/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0037 - val_mae: 0.0437
# Epoch 137/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0037 - val_mae: 0.0436
# Epoch 138/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0037 - val_mae: 0.0437
# Epoch 139/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0037 - val_mae: 0.0438
# Epoch 140/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0038 - val_mae: 0.0441
# Epoch 141/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0037 - val_mae: 0.0439
# Epoch 142/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0037 - val_mae: 0.0439
# Epoch 143/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0038 - val_mae: 0.0445
# Epoch 144/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0038 - val_mae: 0.0444
# Epoch 145/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0038 - val_mae: 0.0440
# Epoch 146/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0039 - val_mae: 0.0448
# Epoch 147/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0038 - val_mae: 0.0441
# Epoch 148/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0039 - val_mae: 0.0450
# Epoch 149/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0037 - val_mae: 0.0437
# Epoch 150/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0326 - val_loss: 0.0040 - val_mae: 0.0458
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mae: 0.0395
# Test Loss: 0.0040, Test MAE: 0.0458
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# MAE: 18.5607
# MSE: 663.0725
# RMSE: 25.7502
# R² Score: 0.5005
