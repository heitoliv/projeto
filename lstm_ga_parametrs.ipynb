# %%
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.optimizers import Adam
import pygad

# Reprodutibilidade
os.environ['PYTHONHASHSEED'] = '42'
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# Dados
df = pd.read_csv('data_per_month.csv')
df = df['Total Renewable Energy']
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(df.values.reshape(-1, 1))

def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

time_steps = 12
X, y = create_sequences(data_scaled, time_steps)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Convertendo os dados para float32 (evita retracing por tipos diferentes)
X_train = X_train.astype(np.float32)
y_train = y_train.astype(np.float32)
X_test = X_test.astype(np.float32)

def build_model(neurons_1, neurons_2, dense_units, learning_rate):
    model = Sequential([
        Input(shape=(time_steps, 1)),
        LSTM(neurons_1, activation='relu', return_sequences=True),
        LSTM(neurons_2, activation='relu'),
        Dense(dense_units, activation='relu'),
        Dense(1)
    ])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse')
    return model

def fitness_func(ga_instance, solution, sol_idx):
    try:
        neurons_1 = int(solution[0])
        neurons_2 = int(solution[1])
        dense_units = int(solution[2])
        learning_rate = float(solution[3])
        batch_size = int(solution[4])
        epochs = int(solution[5])

        neurons_1 = max(8, min(neurons_1, 128))
        neurons_2 = max(8, min(neurons_2, 128))
        dense_units = max(8, min(dense_units, 128))
        learning_rate = max(1e-5, min(learning_rate, 1e-1))
        batch_size = max(8, min(batch_size, 128))
        epochs = max(5, min(epochs, 200))

        print(f"[FITNESS] LSTM1={neurons_1}, LSTM2={neurons_2}, Dense={dense_units}, LR={learning_rate:.5f}, Batch={batch_size}, Epochs={epochs}")

        model = build_model(neurons_1, neurons_2, dense_units, learning_rate)
        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

        preds = model.predict(X_test, verbose=0)
        mse = mean_squared_error(y_test, preds)
        return 1.0 / (mse + 1e-8)

    except Exception as e:
        print(f"[ERRO NA FITNESS] {e}")
        return 0




# ==============================
# BUSCA COM ALGORITMO GENÉTICO
# ==============================
gene_space = [
    {'low': 16, 'high': 128},     # neurônios LSTM camada 1
    {'low': 16, 'high': 128},     # neurônios LSTM camada 2
    {'low': 8, 'high': 64},       # neurônios camada densa
    {'low': 1e-4, 'high': 1e-2},  # taxa de aprendizado
    {'low': 16, 'high': 128},     # tamanho do batch
    {'low': 5, 'high': 30}        # número de épocas
]

ga_instance = pygad.GA(
    num_generations=10,
    num_parents_mating=5,
    fitness_func=fitness_func,
    sol_per_pop=10,
    num_genes=len(gene_space),
    gene_space=gene_space,
    parent_selection_type="rank",
    crossover_type="single_point",
    mutation_type="random",
    mutation_percent_genes=20,
    on_generation=lambda ga: print(f"Ger {ga.generations_completed} - Best fitness: {ga.best_solution()[1]:.6f}")
)

ga_instance.run()

# ==============================
# MELHOR SOLUÇÃO
# ==============================
solution, fitness, _ = ga_instance.best_solution()
print("\nMelhor conjunto de hiperparâmetros encontrados:")
print(f"LSTM1: {int(solution[0])}, LSTM2: {int(solution[1])}")
print(f"Dense: {int(solution[2])}, Learning rate: {solution[3]:.5f}")
print(f"Batch size: {int(solution[4])}, Épocas: {int(solution[5])}")
# Out:
# [FITNESS] LSTM1=57, LSTM2=122, Dense=48, LR=0.00603, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00711, Batch=18, Epochs=29
# [FITNESS] LSTM1=109, LSTM2=39, Dense=18, LR=0.00192, Batch=50, Epochs=18
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002B6EE1D3880> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002B6EE1D3880> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [FITNESS] LSTM1=64, LSTM2=48, Dense=42, LR=0.00148, Batch=48, Epochs=14
# [FITNESS] LSTM1=67, LSTM2=103, Dense=19, LR=0.00519, Batch=82, Epochs=6
# [FITNESS] LSTM1=84, LSTM2=35, Dense=11, LR=0.00949, Batch=124, Epochs=25
# [FITNESS] LSTM1=50, LSTM2=26, Dense=46, LR=0.00446, Batch=29, Epochs=17
# [FITNESS] LSTM1=19, LSTM2=117, Dense=22, LR=0.00666, Batch=50, Epochs=18
# [FITNESS] LSTM1=77, LSTM2=36, Dense=62, LR=0.00777, Batch=121, Epochs=27
# [FITNESS] LSTM1=82, LSTM2=119, Dense=12, LR=0.00204, Batch=21, Epochs=13
# [FITNESS] LSTM1=108, LSTM2=39, Dense=18, LR=0.00603, Batch=33, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=122, Dense=48, LR=0.00603, Batch=82, Epochs=5
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00711, Batch=18, Epochs=29
# [FITNESS] LSTM1=22, LSTM2=113, Dense=42, LR=0.00711, Batch=18, Epochs=29
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00711, Batch=50, Epochs=18
# [FITNESS] LSTM1=57, LSTM2=123, Dense=48, LR=0.00603, Batch=33, Epochs=8
# [FITNESS] LSTM1=66, LSTM2=103, Dense=19, LR=0.00519, Batch=82, Epochs=6
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=29
# [FITNESS] LSTM1=22, LSTM2=113, Dense=40, LR=0.00711, Batch=18, Epochs=29
# [FITNESS] LSTM1=108, LSTM2=39, Dense=18, LR=0.00603, Batch=33, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=122, Dense=48, LR=0.00603, Batch=82, Epochs=5
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00711, Batch=18, Epochs=29
# [FITNESS] LSTM1=22, LSTM2=113, Dense=42, LR=0.00711, Batch=18, Epochs=29
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00711, Batch=50, Epochs=18
# [FITNESS] LSTM1=57, LSTM2=123, Dense=48, LR=0.00603, Batch=33, Epochs=8
# [FITNESS] LSTM1=66, LSTM2=103, Dense=19, LR=0.00519, Batch=82, Epochs=6
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=29
# [FITNESS] LSTM1=22, LSTM2=113, Dense=40, LR=0.00711, Batch=18, Epochs=29
# Ger 1 - Best fitness: 298.535851
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00711, Batch=33, Epochs=8
# [FITNESS] LSTM1=108, LSTM2=39, Dense=48, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=58, LSTM2=123, Dense=48, LR=0.00010, Batch=18, Epochs=29
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=40, LR=0.00711, Batch=18, Epochs=29
# [FITNESS] LSTM1=22, LSTM2=113, Dense=17, LR=0.00603, Batch=33, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=48, LR=0.00603, Batch=33, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=29
# [FITNESS] LSTM1=22, LSTM2=112, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00711, Batch=33, Epochs=8
# [FITNESS] LSTM1=108, LSTM2=39, Dense=48, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=58, LSTM2=123, Dense=48, LR=0.00010, Batch=18, Epochs=29
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=40, LR=0.00711, Batch=18, Epochs=29
# [FITNESS] LSTM1=22, LSTM2=113, Dense=17, LR=0.00603, Batch=33, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=48, LR=0.00603, Batch=33, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=29
# [FITNESS] LSTM1=22, LSTM2=112, Dense=41, LR=0.00010, Batch=33, Epochs=8
# Ger 2 - Best fitness: 237.642595
# [FITNESS] LSTM1=23, LSTM2=113, Dense=41, LR=0.00711, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=112, Dense=41, LR=0.00010, Batch=18, Epochs=29
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=108, LSTM2=39, Dense=48, LR=0.00711, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=112, Dense=40, LR=0.00711, Batch=18, Epochs=29
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=9
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=17, Epochs=8
# [FITNESS] LSTM1=23, LSTM2=113, Dense=41, LR=0.00711, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=112, Dense=41, LR=0.00010, Batch=18, Epochs=29
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=108, LSTM2=39, Dense=48, LR=0.00711, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=112, Dense=40, LR=0.00711, Batch=18, Epochs=29
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=9
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=17, Epochs=8
# Ger 3 - Best fitness: 259.328254
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=17, Epochs=9
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=108, LSTM2=39, Dense=48, LR=0.00711, Batch=34, Epochs=8
# [FITNESS] LSTM1=108, LSTM2=39, Dense=41, LR=0.00711, Batch=33, Epochs=8
# [FITNESS] LSTM1=23, LSTM2=113, Dense=41, LR=0.00711, Batch=33, Epochs=9
# [FITNESS] LSTM1=58, LSTM2=123, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=17, Epochs=9
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=108, LSTM2=39, Dense=48, LR=0.00711, Batch=34, Epochs=8
# [FITNESS] LSTM1=108, LSTM2=39, Dense=41, LR=0.00711, Batch=33, Epochs=8
# [FITNESS] LSTM1=23, LSTM2=113, Dense=41, LR=0.00711, Batch=33, Epochs=9
# [FITNESS] LSTM1=58, LSTM2=123, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# Ger 4 - Best fitness: 237.642595
# [FITNESS] LSTM1=58, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00711, Batch=33, Epochs=10
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=123, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=9
# [FITNESS] LSTM1=23, LSTM2=113, Dense=41, LR=0.00711, Batch=18, Epochs=8
# [FITNESS] LSTM1=58, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00711, Batch=33, Epochs=10
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=123, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=57, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=9
# [FITNESS] LSTM1=23, LSTM2=113, Dense=41, LR=0.00711, Batch=18, Epochs=8
# Ger 5 - Best fitness: 237.642595
# [FITNESS] LSTM1=21, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=9
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=9
# [FITNESS] LSTM1=21, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=9
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=123, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=9
# Ger 6 - Best fitness: 237.642595
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=17, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=17, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# Ger 7 - Best fitness: 237.642595
# [FITNESS] LSTM1=22, LSTM2=112, Dense=41, LR=0.00010, Batch=17, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=17, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=42, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=42, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=34, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=112, Dense=41, LR=0.00010, Batch=17, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=17, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=42, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=42, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=34, Epochs=8
# Ger 8 - Best fitness: 237.642595
# [FITNESS] LSTM1=22, LSTM2=112, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=34, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=42, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=42, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=112, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=34, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=42, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=42, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=113, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=41, LR=0.00010, Batch=18, Epochs=8
# Ger 9 - Best fitness: 237.642595
# [FITNESS] LSTM1=21, LSTM2=112, Dense=42, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=34, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=7
# [FITNESS] LSTM1=22, LSTM2=112, Dense=42, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=112, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=40, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=42, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=34, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=7
# [FITNESS] LSTM1=22, LSTM2=112, Dense=42, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=112, Dense=41, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=40, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
# Ger 10 - Best fitness: 237.642595
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=34, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=41, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=21, LSTM2=112, Dense=42, LR=0.00010, Batch=18, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=40, LR=0.00010, Batch=33, Epochs=8
# [FITNESS] LSTM1=22, LSTM2=113, Dense=41, LR=0.00010, Batch=33, Epochs=8
#
# Melhor conjunto de hiperparâmetros encontrados:
# LSTM1: 22, LSTM2: 113
# Dense: 41, Learning rate: 0.00711
# Batch size: 18, Épocas: 29

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# Reprodutibilidade
os.environ['PYTHONHASHSEED'] = '42'
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# Função para criar sequência de dados
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

# Definir tamanho da janela
time_steps = 12
X, y = create_sequences(data_scaled, time_steps)

# Divisão dos dados
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Construção da rede LSTM
model = Sequential([
    Input(shape=((time_steps, 1))),
    LSTM(22, activation='relu', return_sequences=True),
    LSTM(113, activation='relu'),
    Dense(41, activation='relu'),
    Dense(1)
])
optimizer= Adam(learning_rate=0.00711)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# Treinamento do modelo
history = model.fit(X_train, y_train, epochs=29, batch_size=18, validation_data=(X_test, y_test), verbose=1)

# Avaliação do modelo
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}, Test MAE: {test_mae:.4f}')

# Fazer previsões
y_pred = model.predict(X_test)

# Reverter a normalização
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

# Cálculo das métricas de regressão
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_inv, y_pred_inv)

print(f'MAE: {mae:.4f}')
print(f'MSE: {mse:.4f}')
print(f'RMSE: {rmse:.4f}')
print(f'R² Score: {r2:.4f}')

# Plot da curva de aprendizado
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Loss (Treino)')
plt.plot(history.history['val_loss'], label='Loss (Validação)')
plt.xlabel('Épocas')
plt.ylabel('Erro Quadrático Médio')
plt.legend()
plt.title('Curva de Aprendizado')
plt.show()

# Plot dos resultados
plt.figure(figsize=(10, 5))
plt.plot(y_test_inv, label='Real')
plt.plot(y_pred_inv, label='Previsto')
plt.xlabel('Tempo')
plt.ylabel('Número de Passageiros')
plt.legend()
plt.title('Comparação entre valores reais e previstos')
plt.show()
# Out:
# Epoch 1/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0312 - mae: 0.1316 - val_loss: 0.0159 - val_mae: 0.1050
# Epoch 2/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - mae: 0.0429 - val_loss: 0.0047 - val_mae: 0.0559
# Epoch 3/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mae: 0.0412 - val_loss: 0.0050 - val_mae: 0.0568
# Epoch 4/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mae: 0.0407 - val_loss: 0.0048 - val_mae: 0.0555
# Epoch 5/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mae: 0.0406 - val_loss: 0.0048 - val_mae: 0.0554
# Epoch 6/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0404 - val_loss: 0.0047 - val_mae: 0.0549
# Epoch 7/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0401 - val_loss: 0.0046 - val_mae: 0.0547
# Epoch 8/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - mae: 0.0400 - val_loss: 0.0046 - val_mae: 0.0554
# Epoch 9/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mae: 0.0393 - val_loss: 0.0047 - val_mae: 0.0555
# Epoch 10/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0391 - val_loss: 0.0046 - val_mae: 0.0554
# Epoch 11/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0389 - val_loss: 0.0046 - val_mae: 0.0553
# Epoch 12/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0385 - val_loss: 0.0046 - val_mae: 0.0550
# Epoch 13/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0386 - val_loss: 0.0046 - val_mae: 0.0548
# Epoch 14/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0379 - val_loss: 0.0047 - val_mae: 0.0554
# Epoch 15/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0377 - val_loss: 0.0049 - val_mae: 0.0563
# Epoch 16/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0372 - val_loss: 0.0050 - val_mae: 0.0563
# Epoch 17/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0369 - val_loss: 0.0050 - val_mae: 0.0562
# Epoch 18/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0365 - val_loss: 0.0054 - val_mae: 0.0584
# Epoch 19/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0360 - val_loss: 0.0055 - val_mae: 0.0586
# Epoch 20/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0357 - val_loss: 0.0061 - val_mae: 0.0624
# Epoch 21/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0354 - val_loss: 0.0060 - val_mae: 0.0615
# Epoch 22/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0350 - val_loss: 0.0062 - val_mae: 0.0629
# Epoch 23/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0347 - val_loss: 0.0060 - val_mae: 0.0620
# Epoch 24/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0340 - val_loss: 0.0055 - val_mae: 0.0591
# Epoch 25/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0053 - val_mae: 0.0580
# Epoch 26/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0049 - val_mae: 0.0554
# Epoch 27/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0332 - val_loss: 0.0051 - val_mae: 0.0567
# Epoch 28/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0049 - val_mae: 0.0551
# Epoch 29/29
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0329 - val_loss: 0.0052 - val_mae: 0.0575
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0481
# Test Loss: 0.0052, Test MAE: 0.0575
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# MAE: 23.3260
# MSE: 855.6671
# RMSE: 29.2518
# R² Score: 0.3554
